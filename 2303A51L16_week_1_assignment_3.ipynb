# %% [markdown]
# <a href="https://colab.research.google.com/github/Gouthamraju13/2303A51L16-AIML-27/blob/main/2303A51L16_week_1_assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv("2303A51L16 week-1 assignment-3.csv")
data
# Out:
#    S.no        Name  Age   Weight  Height
# 0     1  Karthikeya    19      54     172
# 1     2     Goutham    20      56     168
# 2     3       Manoj    20      58     160

# %%
import pandas as pd
data=pd.read_excel("2303A51L16 week-1 assignment-3.xlsx")
data
# Out:
#    S.no        Name  Age   Weight  Height
# 0     1  Karthikeya    19      54     172
# 1     2     Goutham    20      56     168
# 2     3       Manoj    20      58     160

# %%
import pandas as pd
data=pd.read_table("2303A51L16 week-1 assignment-3.txt")
data
# Out:
#    S.no        Name  Age   Weight  Height
# 0     1  Karthikeya    19      54     172
# 1     2     Goutham    20      56     168
# 2     3       Manoj    20      58     160

# %%
import pandas as pd
url="https://drive.google.com/file/d/1dDrczMFTmJ6CeGLP4tiXvhMOM6mfzkPB/view?usp=drive_link"
data=pd.read_csv("2303A51L16 week-1 assignment-3.csv")
data
# Out:
#    S.no        Name  Age   Weight  Height
# 0     1  Karthikeya    19      54     172
# 1     2     Goutham    20      56     168
# 2     3       Manoj    20      58     160
